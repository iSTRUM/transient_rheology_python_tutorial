# %% [markdown]
# # testing your environment
#
# Just a test...

# %%
from yt_xarray.sample_data import load_random_xr_data
import yt 
import yt_xarray

fields = {'temperature': ('x', 'y', 'z'), 'pressure': ('x', 'y', 'z')}
dims = {'x': (0,1,15), 'y': (0, 1, 10), 'z': (0, 1, 15)}
ds = load_random_xr_data(fields, dims, length_unit='m')
yt_ds = ds.yt.load_grid()

yt.SlicePlot(yt_ds, 'x', 'temperature')
# Out:
# yt_xarray : [INFO ] 2023-10-18 09:34:01,975:  Inferred geometry type is cartesian. To override, use ds.yt.set_geometry
# yt_xarray : [INFO ] 2023-10-18 09:34:01,976:  Attempting to detect if yt_xarray will require field interpolation:
# yt_xarray : [INFO ] 2023-10-18 09:34:01,976:      Cartesian geometry on uniform grid: yt_xarray will not interpolate.
# yt : [INFO     ] 2023-10-18 09:34:02,033 Parameters: current_time              = 0.0
# yt : [INFO     ] 2023-10-18 09:34:02,034 Parameters: domain_dimensions         = [15 10 15]
# yt : [INFO     ] 2023-10-18 09:34:02,034 Parameters: domain_left_edge          = [-0.03571429 -0.05555556 -0.03571429]
# yt : [INFO     ] 2023-10-18 09:34:02,035 Parameters: domain_right_edge         = [1.03571429 1.05555556 1.03571429]
# yt : [INFO     ] 2023-10-18 09:34:02,035 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2023-10-18 09:34:02,145 xlim = -0.055556 1.055556
# yt : [INFO     ] 2023-10-18 09:34:02,146 ylim = -0.035714 1.035714
# yt : [INFO     ] 2023-10-18 09:34:02,147 xlim = -0.055556 1.055556
# yt : [INFO     ] 2023-10-18 09:34:02,148 ylim = -0.035714 1.035714
# yt : [INFO     ] 2023-10-18 09:34:02,152 Making a fixed resolution buffer of (('gas', 'temperature')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
